# %% [markdown]
# ### Zadanie 1
#
# Dla zbioru danych `zamowienia.csv` wykonaj:
# 1.6 Zbiór z wartościami brakującymi zapisz w oddzielnej zmiennej.

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scipy) (2.1.3)
# Downloading scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 3.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.15.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data/zamowienia.csv', sep=';')

# %%
df2 = df.copy()

# %% [markdown]
# #### 1.1 Wczytaj dane i sprawdź czy są w nim jakieś wartości brakujące.

# %%
df.isnull().sum()
# Out:
# Kraj               0
# Sprzedawca         0
# Data zamowienia    0
# idZamowienia       0
# Utarg              0
# Rok                0
# Miesiąc            0
# year_quarter       0
# dtype: int64

# %% [markdown]
# #### 1.2 W kolumnie `Sprzedawca` zastąp losowo 10% wartości wartością 'BRAK'. (zobacz funkje pseudolosowe w bibliotece pandas lub numpy oraz wykorzystaj ćwiczenia z zajęć poprzednich z indeksowanie danych w ramkach/seriach)

# %%
num_rows = df.shape[0]
num_to_replace = int(0.1 * num_rows)
replace_indices = np.random.choice(df.index, num_to_replace, replace=False)

# %%
df2.loc[replace_indices, 'Sprzedawca'] = 'BRAK'
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16         10248   440.00
# 1    Polska   Sowiński      2003-07-10         10249  1863.40
# 2    Niemcy       BRAK      2003-07-12         10250  1552.60
# 3    Niemcy  Leverling      2003-07-15         10251   654.06
# 4    Niemcy    Peacock      2003-07-11         10252  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK      2005-04-30         11048   525.00
# 795  Niemcy  Leverling      2005-05-01         11052  1332.00
# 796  Niemcy     Fuller      2005-04-29         11053  3055.00
# 797  Niemcy   Callahan      2005-05-01         11056  3740.00
# 798  Niemcy  Leverling      2005-05-01         11057    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# #### 1.3 W kolumnie `idZamowienia` zastąp 5% wartości wartością `np.nan`.

# %%
num_to_replace = int(0.05 * num_rows)
replace_indices = np.random.choice(df.index, num_to_replace, replace=False)

# %%
df2.loc[replace_indices, 'idZamowienia'] = np.nan
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16       10248.0   440.00
# 1    Polska   Sowiński      2003-07-10       10249.0  1863.40
# 2    Niemcy       BRAK      2003-07-12           NaN  1552.60
# 3    Niemcy  Leverling      2003-07-15       10251.0   654.06
# 4    Niemcy    Peacock      2003-07-11       10252.0  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK      2005-04-30           NaN   525.00
# 795  Niemcy  Leverling      2005-05-01       11052.0  1332.00
# 796  Niemcy     Fuller      2005-04-29       11053.0  3055.00
# 797  Niemcy   Callahan      2005-05-01           NaN  3740.00
# 798  Niemcy  Leverling      2005-05-01       11057.0    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# #### 1.4 W kolumnie `Data zamówienia` zastąp 20% wartości wartością `np.nan`.

# %%
num_to_replace = int(0.2 * num_rows)
replace_indices = np.random.choice(df.index, num_to_replace, replace=False)

# %%
df2.loc[replace_indices, 'Data zamowienia'] = np.nan
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16       10248.0   440.00
# 1    Polska   Sowiński      2003-07-10       10249.0  1863.40
# 2    Niemcy       BRAK      2003-07-12           NaN  1552.60
# 3    Niemcy  Leverling      2003-07-15       10251.0   654.06
# 4    Niemcy    Peacock             NaN       10252.0  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK             NaN           NaN   525.00
# 795  Niemcy  Leverling      2005-05-01       11052.0  1332.00
# 796  Niemcy     Fuller      2005-04-29       11053.0  3055.00
# 797  Niemcy   Callahan      2005-05-01           NaN  3740.00
# 798  Niemcy  Leverling      2005-05-01       11057.0    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# #### 1.5 W kolumnie `Utarg` zastąp 15% wartości wartością `np.nan`.

# %%
num_to_replace = int(0.15 * num_rows)
replace_indices = np.random.choice(df.index, num_to_replace, replace=False)

# %%
df2.loc[replace_indices, 'Utarg'] = np.nan
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16       10248.0   440.00
# 1    Polska   Sowiński      2003-07-10       10249.0  1863.40
# 2    Niemcy       BRAK      2003-07-12           0.0  1552.60
# 3    Niemcy  Leverling      2003-07-15       10251.0   654.06
# 4    Niemcy    Peacock      2003-07-15       10252.0  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK      2005-04-24           0.0   525.00
# 795  Niemcy  Leverling      2005-05-01       11052.0  1332.00
# 796  Niemcy     Fuller      2005-04-29       11053.0  3055.00
# 797  Niemcy   Callahan      2005-05-01           0.0  3740.00
# 798  Niemcy  Leverling      2005-05-01       11057.0    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# ### Zadanie 2
#
# Dla nowego zbioru (z wartościami brakującymi) z zadania 1 wykonaj:

# %% [markdown]
# #### 2.1 Zastąp wartości brakujące w kolumnie `idZamowienia` wartością 0.

# %%
df2['idZamowienia']= df2['idZamowienia'].fillna(0)
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16       10248.0   440.00
# 1    Polska   Sowiński      2003-07-10       10249.0  1863.40
# 2    Niemcy       BRAK      2003-07-12           0.0  1552.60
# 3    Niemcy  Leverling      2003-07-15       10251.0   654.06
# 4    Niemcy    Peacock             NaN       10252.0  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK             NaN           0.0   525.00
# 795  Niemcy  Leverling      2005-05-01       11052.0      NaN
# 796  Niemcy     Fuller      2005-04-29       11053.0  3055.00
# 797  Niemcy   Callahan      2005-05-01           0.0  3740.00
# 798  Niemcy  Leverling      2005-05-01       11057.0    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# #### 2.2 Zastąp wartości brakujące w kolumnie `Data zamówienia` wartościami w przód (ffill()).

# %%
df2['Data zamowienia'] = df2['Data zamowienia'].ffill()
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16       10248.0   440.00
# 1    Polska   Sowiński      2003-07-10       10249.0  1863.40
# 2    Niemcy       BRAK      2003-07-12           0.0  1552.60
# 3    Niemcy  Leverling      2003-07-15       10251.0   654.06
# 4    Niemcy    Peacock      2003-07-15       10252.0  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK      2005-04-24           0.0   525.00
# 795  Niemcy  Leverling      2005-05-01       11052.0      NaN
# 796  Niemcy     Fuller      2005-04-29       11053.0  3055.00
# 797  Niemcy   Callahan      2005-05-01           0.0  3740.00
# 798  Niemcy  Leverling      2005-05-01       11057.0    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# #### 2.3 Zastąp wartości brakujące w kolumnie `Utarg` wartością średnią dla danego kraju.

# %%
df2['Utarg'] = df.groupby('Kraj')['Utarg'].transform(lambda x: x.fillna(x.mean()))
df2
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16       10248.0   440.00
# 1    Polska   Sowiński      2003-07-10       10249.0  1863.40
# 2    Niemcy       BRAK      2003-07-12           0.0  1552.60
# 3    Niemcy  Leverling      2003-07-15       10251.0   654.06
# 4    Niemcy    Peacock      2003-07-15       10252.0  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       BRAK      2005-04-24           0.0   525.00
# 795  Niemcy  Leverling      2005-05-01       11052.0  1332.00
# 796  Niemcy     Fuller      2005-04-29       11053.0  3055.00
# 797  Niemcy   Callahan      2005-05-01           0.0  3740.00
# 798  Niemcy  Leverling      2005-05-01       11057.0    45.00
#
# [799 rows x 5 columns]

# %% [markdown]
# ### Zadanie 3
#
# Wyświetl na wykresach typu histogram wraz z funkcją rozkładu (dokładnie tak jak w przykładach powyżej) rozkłady cechy `Utarg` dla zbioru oryginalnego oraz tego po wykonaniu poleceń z zadania 2.

# %%
def compare_distributions(df_1, df_2, bins=10):
    # iterujemy przez cechy do porównania
    for feature in df_1.columns:

        # generujemy dwa histogramy na jednym wykresie
        df_1[feature].hist(bins=bins, figsize=(6, 4), alpha=0.3, density=True, color='g')
        df_1[feature].plot.density(color='g')
        df_2[feature].hist(bins=bins, figsize=(6, 4), alpha=0.3, density=True, color='r')
        df_2[feature].plot.density(color='r')
        plt.title(feature)
        plt.show()

# %%
compare_distributions(df[['Utarg']], df2[['Utarg']], bins=50)

# %% [markdown]
# ### Zadanie 4
#
# Bazując na przykładach z punktu 2 na zbiorze `zamowienia.csv` policz:

# %% [markdown]
# #### 4.1 Średnią wartość zamówienia dla każdego kraju.

# %%
df.groupby('Kraj')['Utarg'].mean().round(3).reset_index(name='Utarg_Kraj_mean')
# Out:
#      Kraj  Utarg_Kraj_mean
# 0  Niemcy         1532.528
# 1  Polska         1550.376

# %% [markdown]
# #### 4.2 Średnią wartość zamówienia dla każdego roku, a następnie miesiąca (grupowanie dwustopniowe)

# %%
df['Data zamowienia'] = pd.to_datetime(df['Data zamowienia'])

df['Rok'] = df['Data zamowienia'].dt.year
df['Miesiąc'] = df['Data zamowienia'].dt.month

# %%
df.groupby(['Rok', 'Miesiąc'])['Utarg'].mean().round(2).reset_index(name='Utarg_mean')
# Out:
#      Rok  Miesiąc  Utarg_mean
# 0   2003        7     1218.25
# 1   2003        8     1097.60
# 2   2003        9      858.58
# 3   2003       10     1456.39
# 4   2003       11     1973.04
# 5   2003       12     1443.09
# 6   2004        1     1914.42
# 7   2004        2     1164.54
# 8   2004        3     1484.82
# 9   2004        4     1053.21
# 10  2004        5     1999.23
# 11  2004        6     1669.43
# 12  2004        7     1211.13
# 13  2004        8     1563.00
# 14  2004        9     1329.14
# 15  2004       10     2064.03
# 16  2004       11     1123.42
# 17  2004       12     1632.98
# 18  2005        1     1487.64
# 19  2005        2     2132.38
# 20  2005        3     1157.16
# 21  2005        4     1931.11
# 22  2005        5     1155.37

# %% [markdown]
# #### 4.3 Liczbę zamówień, którą złożył każdy sprzedawca w danym roku.

# %%
df.groupby(['Rok', 'Sprzedawca'])['idZamowienia'].size().sort_values(ascending=False).reset_index(name='Order_count')
# Out:
#      Rok Sprzedawca  Order_count
# 0   2004    Peacock           78
# 1   2004  Leverling           67
# 2   2004    Davolio           56
# 3   2004   Callahan           55
# 4   2005    Peacock           42
# 5   2004     Fuller           41
# 6   2005  Leverling           40
# 7   2005    Davolio           38
# 8   2005     Fuller           37
# 9   2004       King           34
# 10  2003    Peacock           31
# 11  2004   Sowiński           31
# 12  2005   Callahan           27
# 13  2003    Davolio           23
# 14  2005       King           22
# 15  2005   Sowiński           20
# 16  2004   Kowalski           19
# 17  2004      Dudek           18
# 18  2003  Leverling           18
# 19  2005      Dudek           18
# 20  2003   Callahan           17
# 21  2003   Sowiński           14
# 22  2003     Fuller           14
# 23  2005   Kowalski           13
# 24  2003       King           11
# 25  2003   Kowalski           10
# 26  2003      Dudek            5

# %% [markdown]
# #### 4.4 Nazwę sprzedawcy z każdego kraju, którego sumaryczny utarg był najwyższy.

# %%
seller_order_counts = df.groupby(['Kraj', 'Sprzedawca'])['Utarg'].sum().reset_index(name='Utarg_sum')

seller_order_counts.sort_values(['Kraj', 'Utarg_sum'], ascending=[True, False]).groupby('Kraj').head(1)
# Out:
#      Kraj Sprzedawca  Utarg_sum
# 4  Niemcy    Peacock  225763.68
# 6  Polska       King  116962.99

# %% [markdown]
# #### 4.5 Sumę utargu w każdym kwartale (uwzględnij również rok), i posortuj od wartości najwyższych.

# %%
df['year_quarter'] = df['Data zamowienia'].dt.to_period('Q')
df.groupby('year_quarter')['Utarg'].sum().round(2).sort_values(ascending=False).reset_index(name='Utarg_Quarter_sum')
# Out:
#   year_quarter  Utarg_Quarter_sum
# 0       2005Q1          275985.94
# 1       2004Q4          175168.55
# 2       2005Q2          149834.16
# 3       2004Q2          145654.77
# 4       2004Q3          144320.21
# 5       2004Q1          144047.23
# 6       2003Q4          129331.38
# 7       2003Q3           63985.16
